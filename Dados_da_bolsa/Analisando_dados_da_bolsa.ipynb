# %% [markdown]
# # Analisando dados da Bolsa de Valores
#
# Os dados utilizados nesse *notebook* foram retirados do site yahoo finance.

# %% [markdown]
# ## Importando Bibliotecas

# %%
import plotly
import plotly.offline as py

#Habilita o modo offline
from plotly.offline import plot, iplot
plotly.offline.init_notebook_mode(connected=True)
import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import plotly.io as pio

# %%
import plotly.graph_objs as go

# %% [markdown]
# ## Dados

# %%
df = pd.read_csv('/home/renata/Desktop/Cursos/projetos/Dados_da_bolsa/PETR4.SA.csv')

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close      Volume
# 0  2015-03-18  8.85  9.29  8.67   9.20   8.535496  65324600.0
# 1  2015-03-19  9.18  9.23  8.85   8.92   8.275720  42857200.0
# 2  2015-03-20  9.08  9.35  8.96   9.22   8.554049  65339300.0
# 3  2015-03-23  9.30  9.44  9.20   9.33   8.656107  34124600.0
# 4  2015-03-24  9.37  9.45  9.22   9.42   8.739605  36392400.0

# %%
df.tail()
# Out:
#             Date       Open       High    Low  Close  Adj Close       Volume
# 1239  2020-03-11  16.700001  17.129999  15.00  15.85      15.85  132482400.0
# 1240  2020-03-12  13.660000  13.860000  11.08  12.60      12.60  151535900.0
# 1241  2020-03-13  15.100000  15.400000  12.70  15.40      15.40  174972600.0
# 1242  2020-03-16  12.910000  14.100000  12.55  13.09      13.09  126432800.0
# 1243  2020-03-17  13.600000  13.840000  13.00  13.00      13.00  149228500.0

# %% [markdown]
# ### Visualizando dados

# %%
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook_connected'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %%
pio.renderers.default = 'vscode'

# %% [markdown]
# É definido o renderizador padrão para evitar que dẽ erro depois.

# %%
data = [go.Scatter(
        x = df.Date,
        y = df['Close']
)]

py.iplot(data)

# %% [markdown]
# ### Customizando Faixas de Eixo

# %%
Close = go.Scatter(
    x = df.Date, 
    y = df.Close, 
    name = 'PETR4 Close', 
    line = dict(color = '#17BECF'), 
    opacity = 0.8
)

data = [Close]

layout = dict(
    title = 'Faixa de Data Customizada',
    title_x = 0.5,
    xaxis = dict(
        range = ['2017-01-01', '2017-12-31']
    )
)

fig = dict(data = data, layout = layout)
py.iplot(fig, filename='Manually Set Range')

# %% [markdown]
# ### Rangeslider e Rangeselector

# %%
Close = go.Scatter(
    x = df.Date,
    y = df.Close,
    name = 'PETR4 Close',
    line = dict(color = '#17BECF'),
    opacity = 0.8
)

data = [Close]

layout = dict(
    title = 'Série com Rangeslider e botões',
    title_x = 0.5, 
    xaxis = dict(
        rangeselector = dict(
            buttons = list([
                dict(count = 1,
                    label = '1m', 
                    step = 'month',
                    stepmode = 'backward'),
                dict(count = 6, 
                    label = '6m',
                    step = 'month',
                    stepmode = 'backward'),
                dict(step = 'all')
            ])
        ),
        rangeslider = dict(visible = True),
        type = 'date'
    )
)

fig = dict(data = data, layout = layout)
py.iplot(fig)

# %% [markdown]
# ### Candlesticks
#
# *Candlesticks* são objetos que mostram a variação dos preços conforme as características de abertura, de alta, mínima, fechamento. Mostra a oscilação. *Candlesticks* são gráficos no formato de vela que fornece diversas informações dos preços.

# %%
trace = go.Candlestick(x = df['Date'],
                      open = df['Open'],
                      high = df['High'],
                      low = df['Low'],
                      close = df['Close'])
data = [trace]
py.iplot(data, filename='simple_candlestick')

# %% [markdown]
# O gráfico é formado por diversos pontos que tem o formato de vela. O corpo da vela é a variação da ação entre a abertura e o fechamento, cada corpo tem um tamanho (para facilitar essa visualizaçã dar *zoom* no gráfico), quanto maior for a oscilação diária da ação maior será o corpo da vela e vice-versa. A cor de cada corpo significa se a ação fechou com um preço maior ou menor do que o da abertura, se a cor estiver verde é porque fechou em um preço maior do que da abertura e se tiver vermelho é porque fechou em um valor menor do que o de abertura.
#
# Esse tipo de gráfico é muito utilizado por pessoas que operam a bolsa.

# %% [markdown]
# ### Sem rangeslider

# %%
trace = go.Candlestick(x = df['Date'],
                      open = df['Open'],
                      high = df['High'],
                      low = df['Low'],
                      close = df['Close'])

layout = go.Layout(
    title = 'Preços em Candlestick',
    title_x = 0.5,
    xaxis = dict(
        rangeslider = dict(visible = False)
    )
)

data = [trace]

fig = go.Figure(data = data, layout = layout)
py.iplot(fig)

# %% [markdown]
# #### Customizando Candlesticks

# %%
trace = go.Candlestick(x = df['Date'],
                       open = df['Open'],
                       high = df['High'],
                       low = df['Low'],
                       close = df['Close'],
                       increasing = dict(line = dict(color = '#17BECF')),
                       decreasing = dict(line = dict(color = '#7F7F7F'))
                       )
layout = go.Layout(
    title = 'Preços em Candlesticks',
    title_x = 0.5,
    xaxis = dict(
        rangeslider = dict(visible = False)
    )
)

data = [trace]

fig = go.Figure(data = data, layout = layout)
py.iplot(fig)

# %% [markdown]
# #### Inserindo Anotações

# %%
trace = go.Candlestick(x = df['Date'],
                       open = df['Open'],
                       high = df['High'],
                       low = df['Low'],
                       close = df['Close'],
                       )
layout = {
    'title': 'PETR4 Preços no Período',
    'title_x': 0.5,
    'yaxis': {'title': 'PETR4 Preço'},
    'annotations': [{
        'x': '2017-05-17',
        'y': 15,
        'xref': 'x',
        'yref': 'y',
        'showarrow': True,
        'font': dict(
            family = 'Courier New, monospace',
            size = 12
        ),
        'text': 'Audio Joesley',
        'align': 'center',
        'arrowhead': 2,
        'arrowsize': 1,
        'arrowwidth': 2,
        'bordercolor': '#c7c7c7',
        'borderwidth': 2,
        'borderpad': 4
    },
    {
        'x': '2016-01-01',
        'y': 7,
        'xref': 'x',
        'yref': 'y',
        'showarrow': True,
        'font': dict(
            family = 'Courier New, monospace',
            size = 12
        ),
        'text': 'Impeachment Dilma',
        'align': 'center',
        'arrowhead': 2,
        'arrowsize': 1,
        'arrowwidth': 2,
        'bordercolor': '#c7c7c7',
        'borderwidth': 2,
        'borderpad': 4
    },
    {
        'x': '2018-05-27',
        'y': 27,
        'xref': 'x',
        'yref': 'y',
        'showarrow': True,
        'font': dict(
            family = 'Courier New, monospace',
            size = 12
        ),
        'text': 'Greve dos Caminhoneiros',
        'align': 'center',
        'arrowhead': 2,
        'arrowsize': 1,
        'arrowwidth': 2,
        'bordercolor': '#c7c7c7',
        'borderwidth': 2,
        'borderpad': 4
    }
    ]
}

data = [trace]

fig = go.Figure(data = data, layout = layout)
py.iplot(fig)

# %% [markdown]
# ## Trabalhando com Médias
#
# Para quem faz *trade* trabalhar com média é bastante importante.

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close      Volume
# 0  2015-03-18  8.85  9.29  8.67   9.20   8.535496  65324600.0
# 1  2015-03-19  9.18  9.23  8.85   8.92   8.275720  42857200.0
# 2  2015-03-20  9.08  9.35  8.96   9.22   8.554049  65339300.0
# 3  2015-03-23  9.30  9.44  9.20   9.33   8.656107  34124600.0
# 4  2015-03-24  9.37  9.45  9.22   9.42   8.739605  36392400.0

# %%
#Média simples de 9 dias
df['media_9'] = df.Close.rolling(window = 9).mean()

#Média simples de 17 dias
df['media_17'] = df.Close.rolling(window = 17).mean()

# %%
df.head(20)
# Out:
#           Date   Open   High    Low  Close  Adj Close       Volume    media_9  \
# 0   2015-03-18   8.85   9.29   8.67   9.20   8.535496   65324600.0        NaN
# 1   2015-03-19   9.18   9.23   8.85   8.92   8.275720   42857200.0        NaN
# 2   2015-03-20   9.08   9.35   8.96   9.22   8.554049   65339300.0        NaN
# 3   2015-03-23   9.30   9.44   9.20   9.33   8.656107   34124600.0        NaN
# 4   2015-03-24   9.37   9.45   9.22   9.42   8.739605   36392400.0        NaN
# 5   2015-03-25   9.65   9.89   9.53   9.80   9.092156   84659600.0        NaN
# 6   2015-03-26   9.92   9.96   9.31   9.33   8.656107   58862000.0        NaN
# 7   2015-03-27   9.30   9.61   9.17   9.36   8.683939   51152500.0        NaN
# 8   2015-03-30   9.50   9.75   9.42   9.71   9.008658   33372200.0   9.365556
# 9   2015-03-31   9.58   9.92   9.47   9.66   8.962270   46908300.0   9.416667
# 10  2015-04-01   9.93  10.37   9.87  10.26   9.518934   59374600.0   9.565556
# 11  2015-04-02  10.17  10.72  10.17  10.69   9.917873   69001800.0   9.728889
# 12  2015-04-06  10.80  10.99  10.68  10.71   9.936431   45227600.0   9.882222
# 13  2015-04-07  10.60  10.96  10.46  10.92  10.131264   61721500.0  10.048889
# 14  2015-04-08  11.10  11.33  10.49  10.57   9.806541   73904600.0  10.134444
# 15  2015-04-09  10.70  11.60  10.58  11.58  10.743590   79280800.0  10.384444
# 16  2015-04-10  11.52  11.93  11.27  11.81  10.956979   70021600.0  10.656667
# 17  2015-04-13  11.97  12.75  11.90  12.27  11.383754  104809600.0  10.941111
# 18  2015-04-14  12.67  12.74  11.97  12.46  11.560029   87127100.0  11.252222
# 19  2015-04-15  12.70  13.38  12.47  13.34  12.376469  103042800.0  11.594444
#
#      media_17
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16  10.028824
# 17  10.209412
# 18  10.417647
# 19  10.660000

# %% [markdown]
# ### Plotar as médias e os preços

# %%
close = go.Scatter(
                    x = df['Date'],
                    y = df['Close'],
                    name = 'PETR4 Close',
                    line = dict(color = '#330000'),
                    opacity = 0.8
)

media_9 = go.Scatter(
                    x = df['Date'],
                    y = df['media_9'],
                    name = 'Média no Período de 9 dias',
                    line = dict(color = '#B2FF66'),
                    opacity = 0.8
)

media_17 = go.Scatter(
                    x = df['Date'],
                    y = df['media_17'],
                    name = 'Média no Período de 17 dias',
                    line = dict(color = '#FF00FF'),
                    opacity = 0.8
)

data = [close, media_9, media_17]

py.iplot(data)

# %%
#Média simples 3 dias 
df['media_3'] = df.Close.rolling(window = 3).mean()

# %%
close = go.Scatter(
                    x = df['Date'],
                    y = df['Close'],
                    name = 'PETR4 Close',
                    line = dict(color = '#330000'),
                    opacity = 0.8
)

media_3 = go.Scatter(
                    x = df['Date'],
                    y = df['media_3'],
                    name = 'Média no Período de 3 dias',
                    line = dict(color = '#FF8000'),
                    opacity = 0.8
)

media_9 = go.Scatter(
                    x = df['Date'],
                    y = df['media_9'],
                    name = 'Média no Período de 9 dias',
                    line = dict(color = '#B2FF66'),
                    opacity = 0.8
)

media_17 = go.Scatter(
                    x = df['Date'],
                    y = df['media_17'],
                    name = 'Média no Período de 17 dias',
                    line = dict(color = '#FF00FF'),
                    opacity = 0.8
)

data = [close, media_3, media_9, media_17]

py.iplot(data)

# %% [markdown]
# ### Trabalhando com Médias menores

# %%
#Média simples de 3 dias
df['media_3'] = df.Close.rolling(window = 3).mean()

#Média simples de 7 dias
df['media_7'] = df.Close.rolling(window = 7).mean()

# %%
close = go.Scatter(
                    x = df['Date'],
                    y = df['Close'],
                    name = 'PETR4 Close',
                    line = dict(color = '#330000'),
                    opacity = 0.8
)

media_3 = go.Scatter(
                    x = df['Date'],
                    y = df['media_3'],
                    name = 'Média no Período de 3 dias',
                    line = dict(color = '#B2FF66'),
                    opacity = 0.8
)

media_7 = go.Scatter(
                    x = df['Date'],
                    y = df['media_7'],
                    name = 'Média no Período de 7 dias',
                    line = dict(color = '#CC00CC'),
                    opacity = 0.8
)

data = [close, media_3, media_7]

py.iplot(data)
